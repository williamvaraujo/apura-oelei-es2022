# %% [markdown]
# # Fundamentação:

# %% [markdown]
# 1 - Importar as tabelas necessárias do site do TSE
#
# 2 - Alocar em uma pasta e com nomes organizados
#
# CAMINHO PELO SQL
#
# 3 - Abrir um aplicativo de data do SQL
#
# 4 - Criar um BD
#
# 5 - Importar as tabelas para dentro do DB Browser (SQL Lite)
#
# 6 - Fazer querys para limpeza e consolidação das tabelas
#
# 7 - Exportar as tabelas para o Google Chrome Spreadsheet
#
# CAMINHO PELO PANDAS
#
# 3 - trabalhar a limpeza de cada tabela com o Pandas
#
# 4 - criar uma nova tabela integrando as demais
#
# 5 - exportar para o Google Chrome Spreadsheet

# %%
#1 - Importação das bibliotecas necessárias

import pandas as pd #esta biblioteca servirá para limpar as tabelas e consolidar os dados
from selenium import webdriver #esta biblioteca serve para comandar o navegador por meio de um bot
from webdriver_manager.chrome import ChromeDriverManager #esta biblioteca serve para atualizar o controlador do navegador
from selenium.webdriver.chrome.service import Service #esta biblioteca serve para atualizar o serviço automaticamente
from bs4 import BeautifulSoup
import os
import zipfile as zp
import altair as alt
import numpy as np
import missingno as msno
import re
import unidecode
import unicodedata
import pandasql as ps

# %%
#2 - Criando o controlador do navegador e fazendo com que atualize automaticamente

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

#3 - Raspando as tabelas do TSE
    #Tabela candidatos
site = 'https://dadosabertos.tse.jus.br/dataset/?q=2022'
navegador.get(site)
navegador.find_element('xpath','//*[@id="content"]/div[3]/div/section[1]/div/ul/li[11]/div/h2/a').click()
navegador.find_element('xpath','//*[@id="dataset-resources"]/ul/li[1]/a').click()
navegador.find_element('xpath','//*[@id="content"]/div[3]/section/div/p/a').click()

    #Tabela Prestação de contas
navegador.get(site)
navegador.find_element('xpath','//*[@id="content"]/div[3]/div/section[1]/div/ul/li[9]/div/h2/a').click()
navegador.find_element('xpath','//*[@id="dataset-resources"]/ul/li[2]/a').click()
navegador.find_element('xpath','//*[@id="content"]/div[3]/section/div/p/a').click()
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:00<00:00, 11.3MB/s]

# %%
#4 - mudando de lugar os arquivos baixados e fazendo upload deles
#os.listdir(caminho_do_download) - execute este comando para saber o nome dos arquivos da pasta
caminho_do_download = r'C:\Users\Will Araújo\Downloads'
caminho_de_armazenamento = r'C:\Users\Will Araújo\Desktop\Python Jupyther'
os.rename(f'{caminho_do_download}/prestacao_de_contas_eleitorais_candidatos_2022.zip',f'{caminho_de_armazenamento}/prestacao_de_contas_eleitorais_candidatos_2022.zip')
os.rename(f'{caminho_do_download}/consulta_cand_2022.zip',f'{caminho_de_armazenamento}/consulta_cand_2022.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21552\304514854.py in <module>
#       3 caminho_do_download = r'C:\Users\Will Araújo\Downloads'
#       4 caminho_de_armazenamento = r'C:\Users\Will Araújo\Desktop\Python Jupyther'
# ----> 5 os.rename(f'{caminho_do_download}/prestacao_de_contas_eleitorais_candidatos_2022.zip',f'{caminho_de_armazenamento}/prestacao_de_contas_eleitorais_candidatos_2022.zip')
#       6 os.rename(f'{caminho_do_download}/consulta_cand_2022.zip',f'{caminho_de_armazenamento}/consulta_cand_2022.zip')
#
# FileNotFoundError: [WinError 2] O sistema não pode encontrar o arquivo especificado: 'C:\\Users\\Will Araújo\\Downloads/prestacao_de_contas_eleitorais_candidatos_2022.zip' -> 'C:\\Users\\Will Araújo\\Desktop\\Python Jupyther/prestacao_de_contas_eleitorais_candidatos_2022.zip'

# %%
#5 - Descompactando e abrindo o arquivo baixado
#zp.ZipFile('consulta_cand_2022.zip').namelist()
zp.ZipFile('consulta_cand_2022.zip').extract('consulta_cand_2022_BRASIL.csv')

#zp.ZipFile('prestacao_de_contas_eleitorais_candidatos_2022.zip').namelist()
zp.ZipFile('prestacao_de_contas_eleitorais_candidatos_2022.zip').extract('receitas_candidatos_2022_BRASIL.csv')

# %%
#6 - Abrindo as planilhas gerais e limpando com o Pandas (pd).
#Para isso, precisamos transformar os csvs em DataFrame (objetos do Pandas)






tabela_candidatos = pd.read_csv('consulta_cand_2022_BRASIL.csv',
                                sep=';',encoding='ISO-8859-1',
                                low_memory=False).query(' NR_CPF_CANDIDATO != -4  & NR_TURNO == 1')

tabela_candidatos.groupby('NR_CPF_CANDIDATO')

tabela_contas = pd.read_csv('receitas_candidatos_2022_BRASIL.csv',
                            sep=';', encoding='ISO-8859-1', 
                            low_memory=False).query(
    'DS_ORIGEM_RECEITA == "Recursos de outros candidatos" & DS_FONTE_RECEITA =="FUNDO ESPECIAL"')


#tabela_contas
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'ST_TURNO',
#        'TP_PRESTACAO_CONTAS', 'DT_PRESTACAO_CONTAS', 'SQ_PRESTADOR_CONTAS',
#        'SG_UF', 'SG_UE', 'NM_UE', 'NR_CNPJ_PRESTADOR_CONTA', 'CD_CARGO',
#        'DS_CARGO', 'SQ_CANDIDATO', 'NR_CANDIDATO', 'NM_CANDIDATO',
#        'NR_CPF_CANDIDATO', 'NR_CPF_VICE_CANDIDATO', 'NR_PARTIDO', 'SG_PARTIDO',
#        'NM_PARTIDO', 'CD_FONTE_RECEITA', 'DS_FONTE_RECEITA',
#        'CD_ORIGEM_RECEITA', 'DS_ORIGEM_RECEITA', 'CD_NATUREZA_RECEITA',
#        'DS_NATUREZA_RECEITA', 'CD_ESPECIE_RECEITA', 'DS_ESPECIE_RECEITA',
#        'CD_CNAE_DOADOR', 'DS_CNAE_DOADOR', 'NR_CPF_CNPJ_DOADOR', 'NM_DOADOR',
#        'NM_DOADOR_RFB', 'CD_ESFERA_PARTIDARIA_DOADOR',
#        'DS_ESFERA_PARTIDARIA_DOADOR', 'SG_UF_DOADOR', 'CD_MUNICIPIO_DOADOR',
#        'NM_MUNICIPIO_DOADOR', 'SQ_CANDIDATO_DOADOR', 'NR_CANDIDATO_DOADOR',
#        'CD_CARGO_CANDIDATO_DOADOR', 'DS_CARGO_CANDIDATO_DOADOR',
#        'NR_PARTIDO_DOADOR', 'SG_PARTIDO_DOADOR', 'NM_PARTIDO_DOADOR',
#        'NR_RECIBO_DOACAO', 'NR_DOCUMENTO_DOACAO', 'SQ_RECEITA', 'DT_RECEITA',
#        'DS_RECEITA', 'VR_RECEITA'],
#       dtype='object')

# %%
#7 - Selecionando apenas algumas colunas antes do merge
tb_contas = tabela_contas[['VR_RECEITA',
                           'DS_RECEITA',
                           'SQ_CANDIDATO_DOADOR',
                           'NR_CPF_CNPJ_DOADOR',
                           'NR_CANDIDATO_DOADOR',
                           'NM_DOADOR',
                           'CD_CARGO_CANDIDATO_DOADOR',
                           'DS_CARGO_CANDIDATO_DOADOR',
                           'SG_PARTIDO_DOADOR',
                           'TP_PRESTACAO_CONTAS',
                           'SG_UE',
                           'SG_UF_DOADOR',
                           'DS_CARGO',
                           'CD_CARGO',
                           'SQ_CANDIDATO',
                           'NR_CANDIDATO',
                           'NM_CANDIDATO',
                           'NR_CPF_CANDIDATO',
                           'SG_PARTIDO',
                           'DS_FONTE_RECEITA',
                           'DS_ORIGEM_RECEITA',
                           'DS_NATUREZA_RECEITA',
                           'DS_ESPECIE_RECEITA',
                           'NR_RECIBO_DOACAO',
                           'NR_DOCUMENTO_DOACAO']]

tb_candidatos = tabela_candidatos[['SQ_CANDIDATO',
                                   'NR_CANDIDATO',
                                   'NM_CANDIDATO',
                                   'NR_CPF_CANDIDATO',
                                   'DS_GENERO',
                                   'DS_COR_RACA',
                                   'CD_CARGO']]

# %%
#8 - Fazendo merge e unindo as tabelas para candidatos BENEFICIADOS

tb_receitas_cor_genero_candidato = pd.merge(tb_contas,tb_candidatos,how='left',
                                            left_on= ['SQ_CANDIDATO'],
                                            right_on=['SQ_CANDIDATO'])
tb_receitas_cor_genero_candidato
# Out:
#       VR_RECEITA                                         DS_RECEITA  \
# 0       12000,00                                             #NULO#
# 1         600,00                               SEE THRU 4X0 8X35 CM
# 2       30000,00                                             #NULO#
# 3        5611,11       PRODUÇÃO AUDIOVISUAL DE PROPAGANDA ELEITORAL
# 4      210000,00                                             #NULO#
# ...          ...                                                ...
# 15126    1041,67  SERVIÇO DE CRIAÇÃO DE LAYOUTS/ARTES P/ FINS DE...
# 15127     833,34  SERVIÇO DE CAPTAÇÃO/GRAVAÇÃO DE ÁUDIO P/ PROPA...
# 15128     833,33  SERVIÇO DE PRODUÇÃO/EDIÇÃO DE ÁUDIO P/ PROPAGA...
# 15129    7826,09  SERVIÇO DE PRODUÇÃO E GRAVAÇÃO DOPROGRAMA DE T...
# 15130    7500,00                              INSERCOES E PROGRAMAS
#
#        SQ_CANDIDATO_DOADOR  NR_CPF_CNPJ_DOADOR  NR_CANDIDATO_DOADOR  \
# 0                       -1      47508881000110                 2219
# 1             130001607631      47450338000109                 4455
# 2             150001621390      47517337000134                  444
# 3             110001643543      47547289000127                   44
# 4             280001644128      47547890000110                   44
# ...                    ...                 ...                  ...
# 15126         140001596649      47316142000126                   22
# 15127         140001596649      47316142000126                   22
# 15128         140001596649      47316142000126                   22
# 15129         140001596649      47316142000126                   22
# 15130          30001607336      47450202000107                 2020
#
#                                                NM_DOADOR  \
# 0                                 JORGE MOREIRA THEODORO
# 1      ELEICAO 2022 LEONARDO SILVEIRA DE CASTRO PIRES...
# 2      ELEICAO 2022 EFRAIM DE ARAUJO MORAIS FILHO SEN...
# 3                                  MAURO MENDES FERREIRA
# 4        ELEICAO 2022 SORAYA VIEIRA THRONICKE PRESIDENTE
# ...                                                  ...
# 15126      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15127      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15128      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15129      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15130                     MARIA IVONEIDE OLIVEIRA CHAFAS
#
#        CD_CARGO_CANDIDATO_DOADOR DS_CARGO_CANDIDATO_DOADOR SG_PARTIDO_DOADOR  \
# 0                              6          Deputado Federal                PL
# 1                              6          Deputado Federal             UNIÃO
# 2                              5                   Senador             UNIÃO
# 3                              3                Governador             UNIÃO
# 4                              1                Presidente             UNIÃO
# ...                          ...                       ...               ...
# 15126                          3                Governador                PL
# 15127                          3                Governador                PL
# 15128                          3                Governador                PL
# 15129                          3                Governador                PL
# 15130                          6          Deputado Federal               PSC
#
#         TP_PRESTACAO_CONTAS  ... DS_NATUREZA_RECEITA  \
# 0      RELATÓRIO FINANCEIRO  ...          FINANCEIRO
# 1      RELATÓRIO FINANCEIRO  ...           ESTIMÁVEL
# 2      RELATÓRIO FINANCEIRO  ...          FINANCEIRO
# 3                   PARCIAL  ...           ESTIMÁVEL
# 4      RELATÓRIO FINANCEIRO  ...          FINANCEIRO
# ...                     ...  ...                 ...
# 15126                 FINAL  ...           ESTIMÁVEL
# 15127                 FINAL  ...           ESTIMÁVEL
# 15128                 FINAL  ...           ESTIMÁVEL
# 15129                 FINAL  ...           ESTIMÁVEL
# 15130                 FINAL  ...           ESTIMÁVEL
#
#              DS_ESPECIE_RECEITA       NR_RECIBO_DOACAO  NR_DOCUMENTO_DOACAO  \
# 0                        Cheque  445560700000RJ000002E               850041
# 1                      Estimado  449500700000MG000002E               #NULO#
# 2      Transferência eletrônica  447890700000PB000001E      475173370000134
# 3                      Estimado  044550600000MT000002E               #NULO#
# 4      Transferência eletrônica  440110700000RN000007E      556811000012455
# ...                         ...                    ...                  ...
# 15126                  Estimado  200220700000PA000008E               #NULO#
# 15127                  Estimado  200220700000PA000007E               #NULO#
# 15128                  Estimado  200220700000PA000007E               #NULO#
# 15129                  Estimado  200220700000PA000009E               #NULO#
# 15130                  Estimado  205000700000AP000001E               #NULO#
#
#        NR_CANDIDATO_y                  NM_CANDIDATO_y NR_CPF_CANDIDATO_y  \
# 0               44556    DANIEL PENNA FIRME GUIMARAES        98417274715
# 1               44950        CARLOS GUILHERME DA CRUZ         4705139690
# 2               44789           FLÁVIO OLIVEIRA SILVA        79024483468
# 3                4455    TULIO MARCOS CASADO DA SILVA        48344117100
# 4               44011           MARTA ANTUNES BRANDÃO        73743640406
# ...               ...                             ...                ...
# 15126           20022  EDUARDO JOSÉ MONTEIRO DA COSTA        60738197220
# 15127           20022  EDUARDO JOSÉ MONTEIRO DA COSTA        60738197220
# 15128           20022  EDUARDO JOSÉ MONTEIRO DA COSTA        60738197220
# 15129           20022  EDUARDO JOSÉ MONTEIRO DA COSTA        60738197220
# 15130           20500     JOSÉ LUIZ DA SILVA FERREIRA        17979145291
#
#        DS_GENERO DS_COR_RACA CD_CARGO_y
# 0      MASCULINO      BRANCA          7
# 1      MASCULINO       PARDA          7
# 2      MASCULINO       PARDA          7
# 3      MASCULINO      BRANCA          6
# 4       FEMININO      BRANCA          7
# ...          ...         ...        ...
# 15126  MASCULINO      BRANCA          7
# 15127  MASCULINO      BRANCA          7
# 15128  MASCULINO      BRANCA          7
# 15129  MASCULINO      BRANCA          7
# 15130  MASCULINO       PRETA          7
#
# [15131 rows x 31 columns]

# %%
#9 - Fazendo merge e unindo as tabelas para candidatos DOADORES

tb_comp = pd.merge(tb_receitas_cor_genero_candidato,tb_candidatos,how='left', left_on = ['SQ_CANDIDATO_DOADOR',
                                                                         'NR_CANDIDATO_DOADOR',
                                                                         'CD_CARGO_CANDIDATO_DOADOR'],
                             right_on=['SQ_CANDIDATO',
                                       'NR_CANDIDATO',
                                       'CD_CARGO'],
                             suffixes=('_contas', '_cand'))
tb_comp.keys()
# Out:
# Index(['VR_RECEITA', 'DS_RECEITA', 'SQ_CANDIDATO_DOADOR', 'NR_CPF_CNPJ_DOADOR',
#        'NR_CANDIDATO_DOADOR', 'NM_DOADOR', 'CD_CARGO_CANDIDATO_DOADOR',
#        'DS_CARGO_CANDIDATO_DOADOR', 'SG_PARTIDO_DOADOR', 'TP_PRESTACAO_CONTAS',
#        'SG_UE', 'SG_UF_DOADOR', 'DS_CARGO', 'CD_CARGO_x',
#        'SQ_CANDIDATO_contas', 'NR_CANDIDATO_x', 'NM_CANDIDATO_x',
#        'NR_CPF_CANDIDATO_x', 'SG_PARTIDO', 'DS_FONTE_RECEITA',
#        'DS_ORIGEM_RECEITA', 'DS_NATUREZA_RECEITA', 'DS_ESPECIE_RECEITA',
#        'NR_RECIBO_DOACAO', 'NR_DOCUMENTO_DOACAO', 'NR_CANDIDATO_y',
#        'NM_CANDIDATO_y', 'NR_CPF_CANDIDATO_y', 'DS_GENERO_contas',
#        'DS_COR_RACA_contas', 'CD_CARGO_y', 'SQ_CANDIDATO_cand', 'NR_CANDIDATO',
#        'NM_CANDIDATO', 'NR_CPF_CANDIDATO', 'DS_GENERO_cand',
#        'DS_COR_RACA_cand', 'CD_CARGO'],
#       dtype='object')

# %%
#10 - Renomeando as colunas para melhorar o entendimento
tb_comp_renomeada = tb_comp.rename(columns={'VR_RECEITA':'doacao',
            'DS_RECEITA':'intencao',
            'SQ_CANDIDATO_DOADOR':'cod_doador',
            'NR_CPF_CNPJ_DOADOR':'cnpj_cpf_doador',
            'NR_CANDIDATO_DOADOR':'nr_doador',
            'NM_DOADOR':'nome_doador',
            'DS_GENERO_cand':'gen_doador',
            'DS_COR_RACA_cand':'cor_doador',
            'DS_CARGO_CANDIDATO_DOADOR':'cargo_doador',
            'SG_PARTIDO_DOADOR':'partido_doador',
            'SG_UF_DOADOR':'estado_doador',
            'TP_PRESTACAO_CONTAS':'tipo_prestacao_contas',
            'SQ_CANDIDATO_contas':'sq_beneficiado',
            'NR_CANDIDATO_x':'nr_beneficiado',
            'NR_CPF_CANDIDATO_x':'nr_cpf_beneficiado',
            'NM_CANDIDATO_x':'nome_beneficiado',
            'DS_GENERO_contas':'gen_beneficiado',
            'DS_COR_RACA_contas':'cor_beneficiado',
            'DS_CARGO':'cargo_beneficiado',
            'SG_PARTIDO':'partido_beneficiado',
            'SG_UE':'estado_beneficiado',
            'DS_FONTE_RECEITA':'fonte_receita',
            'DS_ORIGEM_RECEITA':'origem_valor',
            'DS_NATUREZA_RECEITA':'natureza_valor',
            'DS_ESPECIE_RECEITA':'especie_receita',
            'NR_RECIBO_DOACAO':'recibo_doacao',
            'NR_DOCUMENTO_DOACAO':'cod_doc_doacao'
                                             })
tb_comp_renomeada
# Out:
#           doacao                                           intencao  \
# 0       12000,00                                             #NULO#
# 1         600,00                               SEE THRU 4X0 8X35 CM
# 2       30000,00                                             #NULO#
# 3        5611,11       PRODUÇÃO AUDIOVISUAL DE PROPAGANDA ELEITORAL
# 4      210000,00                                             #NULO#
# ...          ...                                                ...
# 15126    1041,67  SERVIÇO DE CRIAÇÃO DE LAYOUTS/ARTES P/ FINS DE...
# 15127     833,34  SERVIÇO DE CAPTAÇÃO/GRAVAÇÃO DE ÁUDIO P/ PROPA...
# 15128     833,33  SERVIÇO DE PRODUÇÃO/EDIÇÃO DE ÁUDIO P/ PROPAGA...
# 15129    7826,09  SERVIÇO DE PRODUÇÃO E GRAVAÇÃO DOPROGRAMA DE T...
# 15130    7500,00                              INSERCOES E PROGRAMAS
#
#          cod_doador  cnpj_cpf_doador  nr_doador  \
# 0                -1   47508881000110       2219
# 1      130001607631   47450338000109       4455
# 2      150001621390   47517337000134        444
# 3      110001643543   47547289000127         44
# 4      280001644128   47547890000110         44
# ...             ...              ...        ...
# 15126  140001596649   47316142000126         22
# 15127  140001596649   47316142000126         22
# 15128  140001596649   47316142000126         22
# 15129  140001596649   47316142000126         22
# 15130   30001607336   47450202000107       2020
#
#                                              nome_doador  \
# 0                                 JORGE MOREIRA THEODORO
# 1      ELEICAO 2022 LEONARDO SILVEIRA DE CASTRO PIRES...
# 2      ELEICAO 2022 EFRAIM DE ARAUJO MORAIS FILHO SEN...
# 3                                  MAURO MENDES FERREIRA
# 4        ELEICAO 2022 SORAYA VIEIRA THRONICKE PRESIDENTE
# ...                                                  ...
# 15126      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15127      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15128      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15129      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR
# 15130                     MARIA IVONEIDE OLIVEIRA CHAFAS
#
#        CD_CARGO_CANDIDATO_DOADOR      cargo_doador partido_doador  \
# 0                              6  Deputado Federal             PL
# 1                              6  Deputado Federal          UNIÃO
# 2                              5           Senador          UNIÃO
# 3                              3        Governador          UNIÃO
# 4                              1        Presidente          UNIÃO
# ...                          ...               ...            ...
# 15126                          3        Governador             PL
# 15127                          3        Governador             PL
# 15128                          3        Governador             PL
# 15129                          3        Governador             PL
# 15130                          6  Deputado Federal            PSC
#
#       tipo_prestacao_contas  ... gen_beneficiado cor_beneficiado CD_CARGO_y  \
# 0      RELATÓRIO FINANCEIRO  ...       MASCULINO          BRANCA          7
# 1      RELATÓRIO FINANCEIRO  ...       MASCULINO           PARDA          7
# 2      RELATÓRIO FINANCEIRO  ...       MASCULINO           PARDA          7
# 3                   PARCIAL  ...       MASCULINO          BRANCA          6
# 4      RELATÓRIO FINANCEIRO  ...        FEMININO          BRANCA          7
# ...                     ...  ...             ...             ...        ...
# 15126                 FINAL  ...       MASCULINO          BRANCA          7
# 15127                 FINAL  ...       MASCULINO          BRANCA          7
# 15128                 FINAL  ...       MASCULINO          BRANCA          7
# 15129                 FINAL  ...       MASCULINO          BRANCA          7
# 15130                 FINAL  ...       MASCULINO           PRETA          7
#
#        SQ_CANDIDATO_cand  NR_CANDIDATO                       NM_CANDIDATO  \
# 0                    NaN           NaN                                NaN
# 1           1.300016e+11        4455.0  LEONARDO SILVEIRA DE CASTRO PIRES
# 2           1.500016e+11         444.0      EFRAIM DE ARAÚJO MORAIS FILHO
# 3           1.100016e+11          44.0              MAURO MENDES FERREIRA
# 4           2.800016e+11          44.0            SORAYA VIEIRA THRONICKE
# ...                  ...           ...                                ...
# 15126       1.400016e+11          22.0               JOSÉ DA CRUZ MARINHO
# 15127       1.400016e+11          22.0               JOSÉ DA CRUZ MARINHO
# 15128       1.400016e+11          22.0               JOSÉ DA CRUZ MARINHO
# 15129       1.400016e+11          22.0               JOSÉ DA CRUZ MARINHO
# 15130       3.000161e+10        2020.0     MARIA IVONEIDE OLIVEIRA CHAGAS
#
#       NR_CPF_CANDIDATO  gen_doador cor_doador CD_CARGO
# 0                  NaN         NaN        NaN      NaN
# 1         7.794015e+10   MASCULINO     BRANCA      6.0
# 2         7.703384e+08   MASCULINO     BRANCA      5.0
# 3         3.043623e+10   MASCULINO     BRANCA      3.0
# 4         6.083897e+10    FEMININO     BRANCA      1.0
# ...                ...         ...        ...      ...
# 15126     6.651127e+09   MASCULINO     BRANCA      3.0
# 15127     6.651127e+09   MASCULINO     BRANCA      3.0
# 15128     6.651127e+09   MASCULINO     BRANCA      3.0
# 15129     6.651127e+09   MASCULINO     BRANCA      3.0
# 15130     3.058622e+10    FEMININO      PARDA      6.0
#
# [15131 rows x 38 columns]

# %%
#ESCOLHENDO AS COLUNAS

tb_total_sem_limpar = tb_comp_renomeada[['doacao',
            'intencao',
            'cod_doador',
            'cnpj_cpf_doador',
            'nr_doador',
            'nome_doador',
            'gen_doador',
            'cor_doador',
            'cargo_doador',
            'partido_doador',
            'tipo_prestacao_contas',
            'sq_beneficiado',
            'nr_beneficiado',
            'nr_cpf_beneficiado',
            'nome_beneficiado',
            'gen_beneficiado',
            'cor_beneficiado',
            'cargo_beneficiado',
            'partido_beneficiado',
            'fonte_receita',
            'origem_valor',
            'natureza_valor',
            'especie_receita',
            'recibo_doacao',
            'cod_doc_doacao']]

tb_total_sem_limpar
# Out:
#           doacao                                           intencao  \
# 0       12000,00                                             #NULO#
# 1         600,00                               SEE THRU 4X0 8X35 CM
# 2       30000,00                                             #NULO#
# 3        5611,11       PRODUÇÃO AUDIOVISUAL DE PROPAGANDA ELEITORAL
# 4      210000,00                                             #NULO#
# ...          ...                                                ...
# 15126    1041,67  SERVIÇO DE CRIAÇÃO DE LAYOUTS/ARTES P/ FINS DE...
# 15127     833,34  SERVIÇO DE CAPTAÇÃO/GRAVAÇÃO DE ÁUDIO P/ PROPA...
# 15128     833,33  SERVIÇO DE PRODUÇÃO/EDIÇÃO DE ÁUDIO P/ PROPAGA...
# 15129    7826,09  SERVIÇO DE PRODUÇÃO E GRAVAÇÃO DOPROGRAMA DE T...
# 15130    7500,00                              INSERCOES E PROGRAMAS
#
#          cod_doador  cnpj_cpf_doador  nr_doador  \
# 0                -1   47508881000110       2219
# 1      130001607631   47450338000109       4455
# 2      150001621390   47517337000134        444
# 3      110001643543   47547289000127         44
# 4      280001644128   47547890000110         44
# ...             ...              ...        ...
# 15126  140001596649   47316142000126         22
# 15127  140001596649   47316142000126         22
# 15128  140001596649   47316142000126         22
# 15129  140001596649   47316142000126         22
# 15130   30001607336   47450202000107       2020
#
#                                              nome_doador gen_doador  \
# 0                                 JORGE MOREIRA THEODORO        NaN
# 1      ELEICAO 2022 LEONARDO SILVEIRA DE CASTRO PIRES...  MASCULINO
# 2      ELEICAO 2022 EFRAIM DE ARAUJO MORAIS FILHO SEN...  MASCULINO
# 3                                  MAURO MENDES FERREIRA  MASCULINO
# 4        ELEICAO 2022 SORAYA VIEIRA THRONICKE PRESIDENTE   FEMININO
# ...                                                  ...        ...
# 15126      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR  MASCULINO
# 15127      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR  MASCULINO
# 15128      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR  MASCULINO
# 15129      ELEIÇÕES 2022 JOSÉ DA CRUZ MARINHO GOVERNADOR  MASCULINO
# 15130                     MARIA IVONEIDE OLIVEIRA CHAFAS   FEMININO
#
#       cor_doador      cargo_doador partido_doador  ... gen_beneficiado  \
# 0            NaN  Deputado Federal             PL  ...       MASCULINO
# 1         BRANCA  Deputado Federal          UNIÃO  ...       MASCULINO
# 2         BRANCA           Senador          UNIÃO  ...       MASCULINO
# 3         BRANCA        Governador          UNIÃO  ...       MASCULINO
# 4         BRANCA        Presidente          UNIÃO  ...        FEMININO
# ...          ...               ...            ...  ...             ...
# 15126     BRANCA        Governador             PL  ...       MASCULINO
# 15127     BRANCA        Governador             PL  ...       MASCULINO
# 15128     BRANCA        Governador             PL  ...       MASCULINO
# 15129     BRANCA        Governador             PL  ...       MASCULINO
# 15130      PARDA  Deputado Federal            PSC  ...       MASCULINO
#
#        cor_beneficiado  cargo_beneficiado  partido_beneficiado  \
# 0               BRANCA  Deputado Estadual                UNIÃO
# 1                PARDA  Deputado Estadual                UNIÃO
# 2                PARDA  Deputado Estadual                UNIÃO
# 3               BRANCA   Deputado Federal                UNIÃO
# 4               BRANCA  Deputado Estadual                UNIÃO
# ...                ...                ...                  ...
# 15126           BRANCA  Deputado Estadual                  PSC
# 15127           BRANCA  Deputado Estadual                  PSC
# 15128           BRANCA  Deputado Estadual                  PSC
# 15129           BRANCA  Deputado Estadual                  PSC
# 15130            PRETA  Deputado Estadual                  PSC
#
#         fonte_receita                   origem_valor natureza_valor  \
# 0      FUNDO ESPECIAL  Recursos de outros candidatos     FINANCEIRO
# 1      FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 2      FUNDO ESPECIAL  Recursos de outros candidatos     FINANCEIRO
# 3      FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 4      FUNDO ESPECIAL  Recursos de outros candidatos     FINANCEIRO
# ...               ...                            ...            ...
# 15126  FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 15127  FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 15128  FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 15129  FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
# 15130  FUNDO ESPECIAL  Recursos de outros candidatos      ESTIMÁVEL
#
#                 especie_receita          recibo_doacao   cod_doc_doacao
# 0                        Cheque  445560700000RJ000002E           850041
# 1                      Estimado  449500700000MG000002E           #NULO#
# 2      Transferência eletrônica  447890700000PB000001E  475173370000134
# 3                      Estimado  044550600000MT000002E           #NULO#
# 4      Transferência eletrônica  440110700000RN000007E  556811000012455
# ...                         ...                    ...              ...
# 15126                  Estimado  200220700000PA000008E           #NULO#
# 15127                  Estimado  200220700000PA000007E           #NULO#
# 15128                  Estimado  200220700000PA000007E           #NULO#
# 15129                  Estimado  200220700000PA000009E           #NULO#
# 15130                  Estimado  205000700000AP000001E           #NULO#
#
# [15131 rows x 25 columns]

# %%
#EXPORTANDO PARA LIMPAR NO LADO DE FORA

tb_total_sem_limpar.to_csv('receitas_cor_gen_incompleta.csv',index=False)
